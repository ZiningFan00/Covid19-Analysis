# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# ### Read Datasets

# %%
total_df = pd.read_excel (r'total.xlsx')
state_df = pd.read_excel (r'state.xlsx')

# %%
total_df
# Out:
#    State/Territory/Federal Entity  \
# 0                         Alabama
# 1                          Alaska
# 2                  American Samoa
# 3                         Arizona
# 4                        Arkansas
# ..                            ...
# 58                       Virginia
# 59                     Washington
# 60                  West Virginia
# 61                      Wisconsin
# 62                        Wyoming
#
#    Total Doses Administered by State where Administered  \
# 0                                           2,758,021
# 1                                              571.32
# 2                                              39.666
# 3                                           5,337,459
# 4                                           1,885,668
# ..                                                ...
# 58                                          7,185,843
# 59                                          6,293,784
# ...

# %%
total_df.dtypes
# Out:
# State/Territory/Federal Entity                                  object
# Total Doses Administered by State where Administered            object
# Doses Administered per 100k by State where Administered        float64
# 18+ Doses Administered by State where Administered              object
# 18+ Doses Administered per 100K by State where Administered    float64
# dtype: object

# %%
state_df
# Out:
#            date location  total_vaccinations  total_distributed  \
# 0    2021-01-12  Alabama             78134.0           377025.0
# 1    2021-01-13  Alabama             84040.0           378975.0
# 2    2021-01-14  Alabama             92300.0           435350.0
# 3    2021-01-15  Alabama            100567.0           444650.0
# 4    2021-01-16  Alabama                 NaN                NaN
# ...         ...      ...                 ...                ...
# 7623 2021-05-04  Wyoming            361199.0           483595.0
# 7624 2021-05-05  Wyoming            363149.0           485195.0
# 7625 2021-05-06  Wyoming            363390.0           486635.0
# 7626 2021-05-07  Wyoming            367548.0           487055.0
# 7627 2021-05-08  Wyoming            369771.0           490875.0
#
#       people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0               70861.0                                 0.15
# 1               74792.0                                 0.19
# ...

# %%
state_df.dtypes
# Out:
# date                                   datetime64[ns]
# location                                       object
# total_vaccinations                            float64
# total_distributed                             float64
# people_vaccinated                             float64
# people_fully_vaccinated_per_hundred           float64
# total_vaccinations_per_hundred                float64
# people_fully_vaccinated                       float64
# people_vaccinated_per_hundred                 float64
# distributed_per_hundred                       float64
# daily_vaccinations_raw                        float64
# daily_vaccinations                            float64
# daily_vaccinations_per_million                float64
# share_doses_used                              float64
# dtype: object

# %% [markdown]
# ### Total Doses

# %%
total_df.columns = ['State', 'a','b','c','d']

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 13))

# fig.title('Total Doses vs 18+ Doses per 100k')

sns.barplot(ax=axes[0], y = total_df.iloc[:,0], 
            x = total_df.iloc[:,2], 
            data = total_df,
            order = total_df.sort_values('b',ascending = False).State)
sns.barplot(ax=axes[1], y = total_df.iloc[:,0], 
            x = total_df.iloc[:,4], 
            data = total_df,
            order = total_df.sort_values('d',ascending = False).State)

axes[0].set_title('Total Doses per 100k')
axes[1].set_title('18+ Doses per 100k')

plt.tight_layout()

# %% [markdown]
# ### State Doses

# %%
plt.figure(figsize=(20, 15))
sns.lineplot(data=state_df, x="date", 
             y="people_fully_vaccinated_per_hundred",
             hue = "location",
             palette = "Set2")
plt.legend(loc='best')
plt.title("People fully vaccinated per 100")
plt.tight_layout()

# %%
plt.figure(figsize=(20, 15))
sns.lineplot(data=state_df, x="date", 
             y="total_vaccinations_per_hundred",
             hue = "location",
             palette = "Set2")
plt.legend(loc='best')
plt.title("Total Vaccinations per 100")
plt.tight_layout()

# %%
plt.figure(figsize=(20, 15))
sns.lineplot(data=state_df, x="date", 
             y="people_vaccinated_per_hundred",
             hue = "location",
             palette = "Set2")
plt.legend(loc='best')
plt.title("People vaccinated per 100")
plt.tight_layout()

# %%
plt.figure(figsize=(20, 15))
sns.lineplot(data=state_df, x="date", 
             y="daily_vaccinations_per_million",
             hue = "location",
             palette = "Set2")
plt.legend(loc='best')
plt.title("Daily Vaccinations per 1M")
plt.tight_layout()

# %% [markdown]
# ### Take California as an example

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 10))

fig.suptitle('California Data')

sns.lineplot(ax=axes[0, 0], data=state_df.loc[state_df['location'] == 'California'], x="date", 
             y="people_fully_vaccinated_per_hundred",
             palette = "Set2")
sns.lineplot(ax=axes[0, 1], data=state_df.loc[state_df['location'] == 'California'], x="date", 
             y="total_vaccinations_per_hundred",
             palette = "Set2")
sns.lineplot(ax=axes[1, 0], data=state_df.loc[state_df['location'] == 'California'], x="date", 
             y="people_vaccinated_per_hundred",
             palette = "Set2")
sns.lineplot(ax=axes[1, 1], data=state_df.loc[state_df['location'] == 'California'], x="date", 
             y="daily_vaccinations_per_million",
             palette = "Set2")

axes[0,0].set_title('People Fully Vaccinated per 100')
axes[0,1].set_title('Total Vaccinations per 100')
axes[1,0].set_title('People Vaccinated per 100')
axes[1,1].set_title('Daily Vaccinations per 1M')

plt.tight_layout()

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 10))

fig.suptitle('New York Data')

sns.lineplot(ax=axes[0, 0], data=state_df.loc[state_df['location'] == 'New York State'], x="date", 
             y="people_fully_vaccinated_per_hundred",
             palette = "Set2")
sns.lineplot(ax=axes[0, 1], data=state_df.loc[state_df['location'] == 'New York State'], x="date", 
             y="total_vaccinations_per_hundred",
             palette = "Set2")
sns.lineplot(ax=axes[1, 0], data=state_df.loc[state_df['location'] == 'New York State'], x="date", 
             y="people_vaccinated_per_hundred",
             palette = "Set2")
sns.lineplot(ax=axes[1, 1], data=state_df.loc[state_df['location'] == 'New York State'], x="date", 
             y="daily_vaccinations_per_million",
             palette = "Set2")

axes[0,0].set_title('People Fully Vaccinated per 100')
axes[0,1].set_title('Total Vaccinations per 100')
axes[1,0].set_title('People Vaccinated per 100')
axes[1,1].set_title('Daily Vaccinations per 1M')

plt.tight_layout()

# %% [markdown]
# ### Bonus Task

# %%
case_df = pd.read_csv('cases.csv')
case_df['submission_date'] =  pd.to_datetime(case_df['submission_date'])

# %%
case_df.dtypes
# Out:
# submission_date    datetime64[ns]
# state                      object
# tot_cases                   int64
# conf_cases                float64
# prob_cases                float64
# new_case                    int64
# pnew_case                 float64
# tot_death                   int64
# conf_death                float64
# prob_death                float64
# new_death                   int64
# pnew_death                float64
# created_at                 object
# consent_cases              object
# consent_deaths             object
# dtype: object

# %%
case_df.loc[case_df['state'] == 'CA']
# Out:
#       submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 6158       10/06/2020    CA     857408         NaN         NaN      3734
# 6164       02/14/2020    CA        117         NaN         NaN         9
# 6205       02/08/2020    CA         86         NaN         NaN         7
# 6256       03/24/2020    CA      12039         NaN         NaN       838
# 6262       04/11/2020    CA      34157         NaN         NaN      1051
# ...               ...   ...        ...         ...         ...       ...
# 22897      04/29/2021    CA    3647271         NaN         NaN      1612
# 22977      08/20/2020    CA     696564         NaN         NaN      4687
# 22986      04/05/2020    CA      26027         NaN         NaN      1139
# 23051      12/20/2020    CA    2061725         NaN         NaN     20239
# 23100      06/09/2020    CA     167132         NaN         NaN      3992
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# ...

# %%
case_df.loc[case_df['state'] == 'NY']
# Out:
#       submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 17         03/23/2020    NY       8570         NaN         NaN      2447
# 55         03/04/2020    NY          1         NaN         NaN         1
# 103        07/30/2020    NY     189507         NaN         NaN       465
# 209        06/14/2020    NY     173446         NaN         NaN       309
# 215        02/15/2020    NY          0         NaN         NaN         0
# ...               ...   ...        ...         ...         ...       ...
# 29214      08/08/2020    NY     192761         NaN         NaN       377
# 29226      11/18/2020    NY     287050         NaN         NaN      3547
# 29228      02/19/2021    NY     887832         NaN         NaN      3838
# 29230      02/13/2021    NY     867467         NaN         NaN      4182
# 29269      10/04/2020    NY     218165         NaN         NaN       690
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# ...

# %%
plt.figure(figsize=(20, 15))
sns.lineplot(data=case_df, x="conf_cases", 
             y="submission_date",
             hue = "state")
plt.legend(loc='best')
plt.title("Total Cases")
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-137-73a5d8dfe401> in <module>
#       2 sns.lineplot(data=case_df, x="conf_cases",
#       3              y="submission_date",
# ----> 4              hue = "state")
#       5 plt.legend(loc='best')
#       6 plt.title("Total Cases")
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1082         ax = plt.gca()
#    1083
# -> 1084     p.plot(ax, kwargs)
#    1085
#    1086     return ax
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     773                     err = "estimator must be None when specifying units"
# ...
